# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

from fastai.imports import *
from fastai.structured import *
from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display
from sklearn import metrics

# %%
set_plot_sizes(12,14,16)

# %%
types = { 'id' : 'int64',
        'item_nbr': 'int32',
        'store_nbr': 'int8',
        'unit_sales': 'float32',
        'onpromotion': 'object'}

# %%
# %%time
df_all = pd.read_csv('./train.csv', parse_dates=['date'], dtype = types, infer_datetime_format=True)
# Out:
# CPU times: user 1min 45s, sys: 4.96 s, total: 1min 50s
# Wall time: 1min 51s

# %%
df_all.head()
# Out:
#    id       date  store_nbr  item_nbr  unit_sales onpromotion
# 0   0 2013-01-01         25    103665         7.0         NaN
# 1   1 2013-01-01         25    105574         1.0         NaN
# 2   2 2013-01-01         25    105575         2.0         NaN
# 3   3 2013-01-01         25    108079         1.0         NaN
# 4   4 2013-01-01         25    108701         1.0         NaN

# %%
df_all.describe(include='all')
# Out:
#                   id                 date     store_nbr      item_nbr  \
# count   1.254970e+08            125497040  1.254970e+08  1.254970e+08
# unique           NaN                 1684           NaN           NaN
# top              NaN  2017-07-01 00:00:00           NaN           NaN
# freq             NaN               118194           NaN           NaN
# first            NaN  2013-01-01 00:00:00           NaN           NaN
# last             NaN  2017-08-15 00:00:00           NaN           NaN
# mean    6.274852e+07                  NaN  2.746458e+01  9.727692e+05
# std     3.622788e+07                  NaN  1.633051e+01  5.205336e+05
# min     0.000000e+00                  NaN  1.000000e+00  9.699500e+04
# 25%     3.137426e+07                  NaN  1.200000e+01  5.223830e+05
# 50%     6.274852e+07                  NaN  2.800000e+01  9.595000e+05
# 75%     9.412278e+07                  NaN  4.300000e+01  1.354380e+06
# max     1.254970e+08                  NaN  5.400000e+01  2.127114e+06
#
#           unit_sales onpromotion
# count   1.254970e+08   103839389
# unique           NaN           2
# top              NaN       False
# freq             NaN    96028767
# first            NaN         NaN
# last             NaN         NaN
# mean    5.319669e+00         NaN
# std     2.306714e+01         NaN
# min    -1.537200e+04         NaN
# 25%     2.000000e+00         NaN
# 50%     4.000000e+00         NaN
# 75%     9.000000e+00         NaN
# max     8.944000e+04         NaN

# %%
df_all.onpromotion.fillna(False, inplace=True)
#Objects are written as strings:
df_all.onpromotion = df_all.onpromotion.map({'False': False, 'True':True})
df_all.onpromotion = df_all.onpromotion.astype(bool)

# %%
df_all.describe(include = 'all')
# Out:
#                   id                 date     store_nbr      item_nbr  \
# count   1.254970e+08            125497040  1.254970e+08  1.254970e+08
# unique           NaN                 1684           NaN           NaN
# top              NaN  2017-07-01 00:00:00           NaN           NaN
# freq             NaN               118194           NaN           NaN
# first            NaN  2013-01-01 00:00:00           NaN           NaN
# last             NaN  2017-08-15 00:00:00           NaN           NaN
# mean    6.274852e+07                  NaN  2.746458e+01  9.727692e+05
# std     3.622788e+07                  NaN  1.633051e+01  5.205336e+05
# min     0.000000e+00                  NaN  1.000000e+00  9.699500e+04
# 25%     3.137426e+07                  NaN  1.200000e+01  5.223830e+05
# 50%     6.274852e+07                  NaN  2.800000e+01  9.595000e+05
# 75%     9.412278e+07                  NaN  4.300000e+01  1.354380e+06
# max     1.254970e+08                  NaN  5.400000e+01  2.127114e+06
#
#           unit_sales onpromotion
# count   1.254970e+08   125497040
# unique           NaN           2
# top              NaN       False
# freq             NaN    96028767
# first            NaN         NaN
# last             NaN         NaN
# mean    5.319669e+00         NaN
# std     2.306714e+01         NaN
# min    -1.537200e+04         NaN
# 25%     2.000000e+00         NaN
# 50%     4.000000e+00         NaN
# 75%     9.000000e+00         NaN
# max     8.944000e+04         NaN

# %%
df_all.dtypes
# Out:
# id                      int64
# date           datetime64[ns]
# store_nbr                int8
# item_nbr                int32
# unit_sales            float32
# onpromotion              bool
# dtype: object

# %%
df_all.to_feather('./raw_groceries')
